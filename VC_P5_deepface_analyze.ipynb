# %% [markdown]
# # Process image folder

# %%
import os
import cv2
from deepface import DeepFace

folder = './faces'

print(folder)

for file_name in os.listdir(folder):
    # Asume imágenes en formato png o jpg
    if file_name.endswith('.png') or file_name.endswith('.jpg'):
        # Procesa la imagen que asume hay cara, no fuerza la detección
        obj = DeepFace.analyze(img_path = os.path.join(folder, file_name), enforce_detection=False, actions =['age', 'gender', 'race', 'emotion'])
        print(file_name)
        print(obj)
        #print(obj["region"])
        #print(obj["age"])      
        #print(obj["gender"])      
        #print(obj["race"])       
        #print(obj["dominant_race"]) 
        #print(obj["emotion"])
        #print(obj["dominant_emotion"])
# Out:
# ./faces
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]
# 25-11-09 18:47:06 - 🔗 age_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5 to C:\Users\lllrm\.deepface\weights\age_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\lllrm\.deepface\weights\age_model_weights.h5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Action: age:   0%|          | 0/4 [00:29<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#       9 for file_name in os.listdir(folder):
#      10     # Asume imágenes en formato png o jpg
#      11     if file_name.endswith('.png') or file_name.endswith('.jpg'):
#      12         # Procesa la imagen que asume hay cara, no fuerza la detección
# ---> 13         obj = DeepFace.analyze(img_path = os.path.join(folder, file_name), enforce_detection=False, actions =['age', 'gender', 'race', 'emotion'])
#      14         print(file_name)
#      15         print(obj)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\DeepFace.py:263, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     172 def analyze(
#     173     img_path: Union[str, np.ndarray, IO[bytes], List[str], List[np.ndarray], List[IO[bytes]]],
#     174     actions: Union[tuple, list] = ("emotion", "age", "gender", "race"),
#    (...)    180     anti_spoofing: bool = False,
#     181 ) -> Union[List[Dict[str, Any]], List[List[Dict[str, Any]]]]:
#     182     """
#     183     Analyze facial attributes such as age, gender, emotion, and race in the provided image.
#     184     Args:
#    (...)    261             - 'white': Confidence score for White ethnicity.
#     262     """
# --> 263     return demography.analyze(
#     264         img_path=img_path,
#     265         actions=actions,
#     266         enforce_detection=enforce_detection,
#     267         detector_backend=detector_backend,
#     268         align=align,
#     269         expand_percentage=expand_percentage,
#     270         silent=silent,
#     271         anti_spoofing=anti_spoofing,
#     272     )
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\modules\demography.py:197, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     194     obj["dominant_emotion"] = Emotion.labels[np.argmax(emotion_predictions)]
#     196 elif action == "age":
# --> 197     apparent_age = modeling.build_model(
#     198         task="facial_attribute", model_name="Age"
#     199     ).predict(img_content)
#     200     # int cast is for exception - object of type 'float32' is not JSON serializable
#     201     obj["age"] = int(apparent_age)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\modules\modeling.py:101, in build_model(task, model_name)
#      99 model = models[task].get(model_name)
#     100 if model:
# --> 101     cached_models[task][model_name] = model()
#     102 else:
#     103     raise ValueError(f"Invalid model_name passed - {task}/{model_name}")
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\models\demography\Age.py:39, in ApparentAgeClient.__init__(self)
#      38 def __init__(self):
# ---> 39     self.model = load_model()
#      40     self.model_name = "Age"
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\models\demography\Age.py:92, in load_model(url)
#      87 age_model = Model(inputs=model.inputs, outputs=base_model_output)
#      89 # --------------------------
#      90
#      91 # load weights
# ---> 92 weight_file = weight_utils.download_weights_if_necessary(
#      93     file_name="age_model_weights.h5", source_url=url
#      94 )
#      96 age_model = weight_utils.load_model_weights(model=age_model, weight_file=weight_file)
#      98 return age_model
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\commons\weight_utils.py:55, in download_weights_if_necessary(file_name, source_url, compress_type)
#      52 logger.info(f"🔗 {file_name} will be downloaded from {source_url} to {target_file}...")
#      54 if compress_type is None:
# ---> 55     gdown.download(source_url, target_file, quiet=False)
#      56 elif compress_type is not None and compress_type in ALLOWED_COMPRESS_TYPES:
#      57     gdown.download(source_url, f"{target_file}.{compress_type}", quiet=False)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\gdown\download.py:368, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     366     pbar = tqdm.tqdm(total=total, unit="B", initial=start_size, unit_scale=True)
#     367 t_start = time.time()
# --> 368 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     369     f.write(chunk)
#     370     if not quiet:
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Process from webcam

# %%
import cv2
from deepface import DeepFace

vid = cv2.VideoCapture(0)

# font 
font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 1
color = (255, 0, 0) 
thickness = 2 
pos = (50, 50) 
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()
  
    if ret:  
        obj = DeepFace.analyze(img_path = frame, enforce_detection=False, actions =['gender', 'emotion'])
        print(obj)

        # Primera cara
        image = cv2.putText(frame, str(obj[0]['dominant_gender']+' '+obj[0]['dominant_emotion']), pos, font,  
                        fontScale, color, thickness, cv2.LINE_AA) 
        # Muestra fotograma
        cv2.imshow('Vid', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 25-11-09 18:13:42 - Directory C:\Users\lllrm\.deepface has been created
# 25-11-09 18:13:42 - Directory C:\Users\lllrm\.deepface\weights has been created
# Action: gender:   0%|          | 0/2 [00:00<?, ?it/s]
# 25-11-09 18:13:52 - 🔗 gender_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5 to C:\Users\lllrm\.deepface\weights\gender_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\lllrm\.deepface\weights\gender_model_weights.h5
# Action: gender:   0%|          | 0/2 [12:33<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 18
#      15 ret, frame = vid.read()
#      17 if ret:
# ---> 18     obj = DeepFace.analyze(img_path = frame, enforce_detection=False, actions =['gender', 'emotion'])
#      19     print(obj)
#      21     # Primera cara
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\DeepFace.py:263, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     172 def analyze(
#     173     img_path: Union[str, np.ndarray, IO[bytes], List[str], List[np.ndarray], List[IO[bytes]]],
#     174     actions: Union[tuple, list] = ("emotion", "age", "gender", "race"),
#    (...)    180     anti_spoofing: bool = False,
#     181 ) -> Union[List[Dict[str, Any]], List[List[Dict[str, Any]]]]:
#     182     """
#     183     Analyze facial attributes such as age, gender, emotion, and race in the provided image.
#     184     Args:
#    (...)    261             - 'white': Confidence score for White ethnicity.
#     262     """
# --> 263     return demography.analyze(
#     264         img_path=img_path,
#     265         actions=actions,
#     266         enforce_detection=enforce_detection,
#     267         detector_backend=detector_backend,
#     268         align=align,
#     269         expand_percentage=expand_percentage,
#     270         silent=silent,
#     271         anti_spoofing=anti_spoofing,
#     272     )
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\modules\demography.py:204, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     201     obj["age"] = int(apparent_age)
#     203 elif action == "gender":
# --> 204     gender_predictions = modeling.build_model(
#     205         task="facial_attribute", model_name="Gender"
#     206     ).predict(img_content)
#     207     obj["gender"] = {}
#     208     for i, gender_label in enumerate(Gender.labels):
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\modules\modeling.py:101, in build_model(task, model_name)
#      99 model = models[task].get(model_name)
#     100 if model:
# --> 101     cached_models[task][model_name] = model()
#     102 else:
#     103     raise ValueError(f"Invalid model_name passed - {task}/{model_name}")
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\models\demography\Gender.py:41, in GenderClient.__init__(self)
#      40 def __init__(self):
# ---> 41     self.model = load_model()
#      42     self.model_name = "Gender"
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\models\demography\Gender.py:88, in load_model(url)
#      83 gender_model = Model(inputs=model.inputs, outputs=base_model_output)
#      85 # --------------------------
#      86
#      87 # load weights
# ---> 88 weight_file = weight_utils.download_weights_if_necessary(
#      89     file_name="gender_model_weights.h5", source_url=url
#      90 )
#      92 gender_model = weight_utils.load_model_weights(
#      93     model=gender_model, weight_file=weight_file
#      94 )
#      96 return gender_model
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\deepface\commons\weight_utils.py:55, in download_weights_if_necessary(file_name, source_url, compress_type)
#      52 logger.info(f"🔗 {file_name} will be downloaded from {source_url} to {target_file}...")
#      54 if compress_type is None:
# ---> 55     gdown.download(source_url, target_file, quiet=False)
#      56 elif compress_type is not None and compress_type in ALLOWED_COMPRESS_TYPES:
#      57     gdown.download(source_url, f"{target_file}.{compress_type}", quiet=False)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\gdown\download.py:368, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     366     pbar = tqdm.tqdm(total=total, unit="B", initial=start_size, unit_scale=True)
#     367 t_start = time.time()
# --> 368 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     369     f.write(chunk)
#     370     if not quiet:
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\lllrm\anaconda3\envs\VC_P5\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
